# %%
import pandas as pd

# %%
pairs = pd.read_csv('data/curated_pairs.csv', index_col=0)
display(pairs.head())

cpds = pd.read_csv('data/compounds_final.csv', index_col=0)
display(cpds.head())
# Out:
#                                       KEGG_reactions  num_reactions  \
# 0                                      R00104,R00118              2
# 1                                      R00104,R00118              2
# 2  R00114,R00134,R00146,R00205,R00216,R00243,R002...           1357
# 3                                      R00119,R10631              2
# 4                                             R00119              1
#
#    Reactant_pair  source  target        MW  W  I  Se  P  ...  S  F  Fe  Mn  \
# 0  C00003_C00006  C00003  C00006  0.056768  0  0   0  1  ...  0  0   0   0
# 1  C00003_C00006  C00003  C00006  0.056768  0  0   0  1  ...  0  0   0   0
# 2  C00005_C00006  C00005  C00006  0.000677  0  0   0  0  ...  0  0   0   0
# 3  C00153_C00006  C00153  C00006  0.718128  0  0   0  3  ...  0  0   0   0
# 4  C13051_C00006  C13051  C00006  0.000659  0  0   0  0  ...  0  0   0   0
#
#    Mg  polymer  mol_weight  Degree Centrality  PageRank  total_molecules
# 0   0        0      79.978          -0.001288 -0.000245                5
# 1   0        0      79.978          -0.001288 -0.000245                5
# 2   0        0      -1.008           0.000586  0.000114                1
# 3   0        0     622.294           0.000234  0.000057               62
# 4   0        0      -0.982           0.000703  0.000147                3
#
# [5 rows x 35 columns]
#        id        formula  mol_weight  W  I  Se  P   C  Cl   H  ...  Hg  Br  \
# 0  C00001            H2O      18.016  0  0   0  0   0   0   2  ...   0   0
# 1  C00002  C10H16N5O13P3     507.188  0  0   0  3  10   0  16  ...   0   0
# 2  C00003  C21H28N7O14P2     664.444  0  0   0  2  21   0  28  ...   0   0
# 3  C00004  C21H29N7O14P2     665.452  0  0   0  2  21   0  29  ...   0   0
# 4  C00005  C21H30N7O17P3     745.430  0  0   0  3  21   0  30  ...   0   0
#
#    Ni   O  S  F  Fe  Mn  Mg  polymer
# 0   0   1  0  0   0   0   0        0
# 1   0  13  0  0   0   0   0        0
# 2   0  14  0  0   0   0   0        0
# 3   0  14  0  0   0   0   0        0
# 4   0  17  0  0   0   0   0        0
#
# [5 rows x 28 columns]
